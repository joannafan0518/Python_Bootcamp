# %% [markdown]
# # Day 1 Exercises
# ## Data Types

# %% [markdown]
# #### 1. What types are involved in the following expressions? What data type will each expression evaluate to?

# %%
8 * 2.5
# Out:
# 20.0

# %% [markdown]
# int & float. The data type is float.

# %%
9 / 2
# Out:
# 4.5

# %% [markdown]
# int. The data type is float.

# %%
1.5 * 2 >= 7 - 3
# Out:
# False

# %% [markdown]
# int & float. The data type is bool.

# %% [markdown]
# #### 2. In which order will the expressions be evaluated?

# %%
6 * 3 + 7 * 4
# Out:
# 46

# %% [markdown]
# 1. 6 * 3 = 18
# 2. 7 * 4 = 28
# 3. 18 + 28 = 46

# %%
5 - 2 * 3 ** 4
# Out:
# -157

# %% [markdown]
# 1. 3 ** 4 = 81
# 2. 2 * 81 = 162
# 3. 5 - 162 = -157

# %%
(5 - 2) * 3 ** 4
# Out:
# 243

# %% [markdown]
# 1. 5 - 2 = 3
# 2. 3 ** 4 = 81
# 3. 3 * 81 = 243

# %%
5 + 2 >= 3 * 4
# Out:
# False

# %% [markdown]
# 1. 5 + 2 = 7
# 2. 3 * 4 = 12
# 3. 7 < 12
# 4. False

# %% [markdown]
# ## Comments and Errors

# %% [markdown]
# #### 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))
# Out:
# 81920

# %% [markdown]
# No error.

# %%
84 *= 0.5 / 7
# Out:
#   File "/tmp/ipykernel_11770/868797654.py", line 1
#     84 *= 0.5 / 7
#     ^
# SyntaxError: 'literal' is an illegal expression for augmented assignment

# %% [markdown]
# This results in a syntax error.
# Reason: Variable names in Python cannot start with a digit.

# %%
(-(-(-(-5 * (4 + 3)))))
# Out:
# 35

# %% [markdown]
# No error.

# %%
5 * 3 = weight
# Out:
#   File "/tmp/ipykernel_11770/3700621706.py", line 1
#     5 * 3 = weight
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# This results in a syntax error.
# Reason: It's written in the opposite direction

# %%
73 / -----------5
# Out:
# -14.6

# %% [markdown]
# No error.

# %% [markdown]
# #### 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6

# Your code goes here
if (value) == str:
  print ("Valid")
else:
   ("Value must be a string")

# %% [markdown]
# #### 3. What are the following errors?

# %%
arr = [1, 2, 3]
print(arr[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_11770/2963248189.py in <cell line: 0>()
#       1 arr = [1, 2, 3]
# ----> 2 print(arr[3])
#
# IndexError: list index out of range

# %% [markdown]
# Python indexing starts at 0. Here arr[3] tries to access a fourth element, which does not exist.

# %%
fullName = "Taylor Swift"
print(full_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11770/3996353418.py in <cell line: 0>()
#       1 fullName = "Taylor Swift"
# ----> 2 print(full_name)
#
# NameError: name 'full_name' is not defined

# %% [markdown]
# Python is case-sensitive, so "Name" and "name" are treated as two different variable names.

# %%
2 + '2' + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_11770/1647341539.py in <cell line: 0>()
# ----> 1 2 + '2' + 4
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# 2 and 4 are integers, but '2' is a string. Python does not allow adding an int and a str.

# %% [markdown]
# ## Functions

# %% [markdown]
# #### 1. Following the function design recipe, define a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
# Your code goes here
def km_to_miles(distance_km):
  """
  Convert a distance from kilometers to miles.

  Parameters:
    distance_km (float): The distance in kilometers.

  Returns:
    float: The distance in miles.
  """
  return distance_km / 1.6

# %% [markdown]
# #### 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer

answer_to_everything()

print(answer)
# Out:
# 3

# %% [markdown]
# Value printed here is 3. Because "answer = 3" is set as a global variable, but "answer = 42" is set as a local variable, which only exists inside the fonction.

# %% [markdown]
# #### 3. Complete the body of the function. You can assume num is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    ""
    >>> repeat('yesnomaybe', 3)
    "yesnomaybeyesnomaybeyesnomaybe"
    '''

    return output

# %% [markdown]
# #### 4. Complete the function below. You can assume that number will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    # Your code goes here
    # Hint: replace () and spaces with nothing
    def is_416_number(number):
      """
      Check whether the number has a 416 area code.

      Parameters:
        number (str): The phone number to check.

      Returns:
        bool: True if the number has a 416 area code, False otherwise.
      """
      return number[:3] == "416"
